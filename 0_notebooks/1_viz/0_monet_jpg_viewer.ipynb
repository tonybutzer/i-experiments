# %%
dir1='/home/ec2-user/data/thumbnails'

# %%
# %%bash
# dir='/home/ec2-user/data/thumbnails'
# ls -l ${dir}
# Out:
# total 2768
# -rw-r--r-- 1 root root 144582 Sep 12 14:50 20200218_23KPR_00_R10m_TCI.jpg
# -rw-r--r-- 1 root root 145087 Sep 12 14:50 20200324_23KPR_00_R10m_TCI.jpg
# -rw-r--r-- 1 root root 128355 Sep 12 14:50 20200403_23KPR_00_R10m_TCI.jpg
# -rw-r--r-- 1 root root 120179 Sep 12 14:50 20200428_23KPR_00_R10m_TCI.jpg
# -rw-r--r-- 1 root root 146008 Sep 12 14:50 20200508_23KPR_00_R10m_TCI.jpg
# -rw-r--r-- 1 root root 111847 Sep 12 14:50 20200513_23KPR_00_R10m_TCI.jpg
# -rw-r--r-- 1 root root 147762 Sep 12 14:50 20200518_23KPR_00_R10m_TCI.jpg
# -rw-r--r-- 1 root root 135731 Sep 12 14:50 20200528_23KPR_00_R10m_TCI.jpg
# -rw-r--r-- 1 root root 107340 Sep 12 14:50 20200602_23KPR_00_R10m_TCI.jpg
# -rw-r--r-- 1 root root 109034 Sep 12 14:50 20200622_23KPR_00_R10m_TCI.jpg
# -rw-r--r-- 1 root root 121831 Sep 12 14:50 20200627_23KPR_00_R10m_TCI.jpg
# -rw-r--r-- 1 root root 146400 Sep 12 14:50 20200702_23KPR_00_R10m_TCI.jpg
# -rw-r--r-- 1 root root 110795 Sep 12 14:50 20200707_23KPR_00_R10m_TCI.jpg
# -rw-r--r-- 1 root root 131195 Sep 12 14:50 20200717_23KPR_00_R10m_TCI.jpg
# -rw-r--r-- 1 root root 115652 Sep 12 14:50 20200722_23KPR_00_R10m_TCI.jpg
# -rw-r--r-- 1 root root 141265 Sep 12 14:50 20200826_23KPR_00_R10m_TCI.jpg
# -rw-r--r-- 1 root root 115446 Sep 12 14:50 20200831_23KPR_00_R10m_TCI.jpg
# -rw-r--r-- 1 root root 125217 Sep 12 14:50 20200905_23KPR_00_R10m_TCI.jpg
# -rw-r--r-- 1 root root 100480 Sep 12 14:50 20200910_23KPR_00_R10m_TCI.jpg
# -rw-r--r-- 1 root root 144675 Sep 12 14:50 20200925_23KPR_00_R10m_TCI.jpg
# -rw-r--r-- 1 root root 104740 Sep 12 14:50 20200930_23KPR_00_R10m_TCI.jpg
# -rw-r--r-- 1 root root 125608 Sep 12 14:50 20201219_23KPR_00_R10m_TCI.jpg

# %%
from os import listdir
from os.path import isfile, join
mypath=dir1
onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]

# %%
onlyfiles
# Out:
# ['20201219_23KPR_00_R10m_TCI.jpg',
#  '20200930_23KPR_00_R10m_TCI.jpg',
#  '20200925_23KPR_00_R10m_TCI.jpg',
#  '20200910_23KPR_00_R10m_TCI.jpg',
#  '20200905_23KPR_00_R10m_TCI.jpg',
#  '20200831_23KPR_00_R10m_TCI.jpg',
#  '20200826_23KPR_00_R10m_TCI.jpg',
#  '20200722_23KPR_00_R10m_TCI.jpg',
#  '20200717_23KPR_00_R10m_TCI.jpg',
#  '20200707_23KPR_00_R10m_TCI.jpg',
#  '20200702_23KPR_00_R10m_TCI.jpg',
#  '20200627_23KPR_00_R10m_TCI.jpg',
#  '20200622_23KPR_00_R10m_TCI.jpg',
#  '20200602_23KPR_00_R10m_TCI.jpg',
#  '20200528_23KPR_00_R10m_TCI.jpg',
#  '20200518_23KPR_00_R10m_TCI.jpg',
#  '20200513_23KPR_00_R10m_TCI.jpg',
#  '20200508_23KPR_00_R10m_TCI.jpg',
#  '20200428_23KPR_00_R10m_TCI.jpg',
#  '20200403_23KPR_00_R10m_TCI.jpg',
#  '20200324_23KPR_00_R10m_TCI.jpg',
#  '20200218_23KPR_00_R10m_TCI.jpg']

# %%
full_jpg_list=[]
for my_jpg in onlyfiles:
    the_jpg = dir1 + '/' + my_jpg
    #print(the_jpg)
    full_jpg_list.append(the_jpg)
    #please_display(the_jpg)

# %%
from IPython.display import Image, display

listOfImageNames = full_jpg_list

for imageName in listOfImageNames:
    print(imageName)
    display(Image(filename=imageName))
# Out:
# /home/ec2-user/data/thumbnails/20201219_23KPR_00_R10m_TCI.jpg
# /home/ec2-user/data/thumbnails/20200930_23KPR_00_R10m_TCI.jpg
# /home/ec2-user/data/thumbnails/20200925_23KPR_00_R10m_TCI.jpg
# /home/ec2-user/data/thumbnails/20200910_23KPR_00_R10m_TCI.jpg
# /home/ec2-user/data/thumbnails/20200905_23KPR_00_R10m_TCI.jpg
# /home/ec2-user/data/thumbnails/20200831_23KPR_00_R10m_TCI.jpg
# /home/ec2-user/data/thumbnails/20200826_23KPR_00_R10m_TCI.jpg
# /home/ec2-user/data/thumbnails/20200722_23KPR_00_R10m_TCI.jpg
# /home/ec2-user/data/thumbnails/20200717_23KPR_00_R10m_TCI.jpg
# /home/ec2-user/data/thumbnails/20200707_23KPR_00_R10m_TCI.jpg
# /home/ec2-user/data/thumbnails/20200702_23KPR_00_R10m_TCI.jpg
# /home/ec2-user/data/thumbnails/20200627_23KPR_00_R10m_TCI.jpg
# /home/ec2-user/data/thumbnails/20200622_23KPR_00_R10m_TCI.jpg
# /home/ec2-user/data/thumbnails/20200602_23KPR_00_R10m_TCI.jpg
# /home/ec2-user/data/thumbnails/20200528_23KPR_00_R10m_TCI.jpg
# /home/ec2-user/data/thumbnails/20200518_23KPR_00_R10m_TCI.jpg
# /home/ec2-user/data/thumbnails/20200513_23KPR_00_R10m_TCI.jpg
# /home/ec2-user/data/thumbnails/20200508_23KPR_00_R10m_TCI.jpg
# /home/ec2-user/data/thumbnails/20200428_23KPR_00_R10m_TCI.jpg
# /home/ec2-user/data/thumbnails/20200403_23KPR_00_R10m_TCI.jpg
# /home/ec2-user/data/thumbnails/20200324_23KPR_00_R10m_TCI.jpg
# /home/ec2-user/data/thumbnails/20200218_23KPR_00_R10m_TCI.jpg
